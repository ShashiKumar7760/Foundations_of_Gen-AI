# %% [markdown]
# Lab Practical  Python Implementation
#
# Date: 03-02-2026

# %% [markdown]
# Basic Setup:

# %%
pip install groq
# Out:
# Requirement already satisfied: groq in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)

# %%
from groq import Groq

client = Groq(
    api_key="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"
)

# %%
def ask_ai(prompt):
    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

# %%
print("\n=== EXERCISE 3 ===\n")
# Out:
# === EXERCISE 3 ===

# %% [markdown]
# Exercise 3
# Use of Persona Prompt, Root Prompt, Cognitive Verifier Pattern, Question Refinement Pattern, Provide New Information and Ask Questions

# %%
root_prompt = """
You are an expert Generative AI tutor.
Explain concepts clearly, step by step, using simple language.
"""

print("Root Prompt Output:\n")
print(ask_ai(root_prompt + "Explain Prompt Engineering."))
print("-" * 80)
# Out:
# Root Prompt Output:
#
# I'm excited to explain Prompt Engineering to you.
#
# **What is Prompt Engineering?**
#
# Prompt Engineering is the process of creating and refining a clear, concise, and well-formulated input (called a prompt) to generate specific and accurate responses from a Generative AI model. Think of it like asking a librarian to fetch a book; you need to give them the exact title and author to find the right book. Similarly, with Prompt Engineering, you provide the AI with the exact information and context it needs to produce a desired output.
#
# **Key Steps to Effective Prompt Engineering:**
#
# 1. **Define Your Goal**: Identify the specific task or information you want the AI to generate. This could be anything from writing a story to summarizing a passage.
# 2. **Understand the AI's Capabilities**: Familiarize yourself with the AI's strengths, limits, and potential biases. Some AI models excel in certain domains, like language translation or text summarization.
# 3. **Craft a Clear and Constrained Prompt**: A good prompt should be concise, specific, and well-defined. It should also be clear about what is being asked. Try to avoid ambiguity and broad, open-ended questions.
# 4. **Provide Relevant Context**: Give the AI model any relevant information or context it needs to understand the task. This can include domain-specific terms, definitions, or prior knowledge.
# 5. **Test and Refine**: Test the prompt on the AI model to see if it produces the desired output. If not, refine the prompt by gathering more information, rephrasing it, or adjusting the context.
#
# **Example of Prompt Engineering:**
#
# Suppose you want to generate a short story about a character's first day at a new job.
#
# **Original Prompt:**
# "Write a story about a character's new job."
#
# This prompt is too broad and open-ended, and the AI may generate irrelevant or generic content.
#
# **Refined Prompt:**
# "Write a 500-word story about a 30-year-old character's first day as a marketing specialist at a tech startup in New York City. They are excited but nervous, and their main goal is to make a good impression on their new team."
#
# This revised prompt provides specific conditions, context, and constraints, increasing the chances of the AI generating a relevant and engaging story.
#
# In conclusion, Prompt Engineering is an essential skill when working with Generative AI models. By defining your goals, understanding the AI's capabilities, crafting clear and constrained prompts, providing relevant context, and refining the prompt, you can get the most out of these powerful tools.
# --------------------------------------------------------------------------------

# %% [markdown]
# 2.Persona Prompt
# A Persona Prompt assigns a role or identity to the AI (teacher, doctor, mentor, etc.).
# This changes how the AI explains, not what it explains.

# %%
persona_prompt = """
Act as a college professor teaching Generative AI to undergraduate students.
Explain Prompt Engineering with real-life examples.
"""

print("Persona Prompt Output:\n")
print(ask_ai(persona_prompt))
print("-" * 80)
# Out:
# Persona Prompt Output:
#
# Welcome, students, to today's lecture on Generative AI, specifically Prompt Engineering. Prompt Engineering is a crucial aspect of working with Generative AI models, as it involves designing and refining the input prompts to elicit the desired output from the model. This field is rapidly evolving and has numerous applications across various industries.
#
# **What is Prompt Engineering?**
#
# Prompt Engineering is the process of crafting and optimizing input prompts for a Generative AI model to produce the desired output. A well-designed prompt helps the model understand the context, tone, and specific requirements of the task at hand, resulting in a more accurate and relevant output.
#
# **Why is Prompt Engineering important?**
#
# 1. **Improved accuracy**: By refining the prompt, you can direct the model to focus on the specific aspects of the task, leading to more accurate and relevant outputs.
# 2. **Efficient use of resources**: A well-designed prompt can help reduce the number of iterations and resources required to achieve the desired output.
# 3. **Enhanced user experience**: Clear and concise prompts can result in outputs that are easier to understand and more user-friendly.
#
# **Real-life examples of Prompt Engineering:**
#
# 1. **Virtual Assistant**: Designing a prompt that asks, "Recommend a top 3-rated, Italian restaurant in New York for a romantic dinner" would elicit a more relevant response than a generic prompt like "Recommend a good restaurant."
# 2. **Chatbots**: Crafting a prompt like "Explain the concept of climate change in simple terms, with examples of its effects" for a chatbot would produce a more comprehensive and informative response than a vague prompt like "Tell me about climate change."
# 3. **Language Translation**: For translating a medical text from English to Spanish, a prompt like "Translate this medical text with the same formal tone and technical vocabulary" would produce a more accurate translation than a generic prompt like "Translate this text."
# 4. **Creative Writing**: An author might use a prompt like "Write a short story about a character who discovers a hidden world beneath the ocean, inspired by Greek mythology" to elicit more creative and engaging responses from a Generative AI model.
#
# **Best practices for Prompt Engineering:**
#
# 1. **Be clear and concise**: Avoid ambiguity and complexity in your prompts.
# 2. **Use specific language**: Include specific keywords, names, and details to direct the model's attention.
# 3. **Understand the model's strengths and weaknesses**: Recognize the capabilities and limitations of the model and tailor your prompt accordingly.
# 4. **Refine and iterate**: Continuously refine and test your prompts to achieve optimal results.
# 5. **Consider the context**: Take into account the context in which the model will be used, including the user's perspective and goals.
#
# In conclusion, Prompt Engineering is a vital aspect of working with Generative AI models. By understanding and refining your input prompts, you can unlock the full potential of these models and produce more accurate, relevant, and engaging outputs. For your homework assignment, please design and test a series of prompts for a Generative AI model, and submit them by the end of the week.
# --------------------------------------------------------------------------------

# %% [markdown]
# 3.Cognitive Verifier Pattern
# Here the AI:
#
# Answers the question
#
# Checks its own answer
#
# Mentions missing or weak points
#
# This improves accuracy and reliability.

# %%
cognitive_verifier_prompt = """
Explain what Prompt Engineering is.
After answering, verify your response and mention if anything is missing.
"""

print("Cognitive Verifier Output:\n")
print(ask_ai(cognitive_verifier_prompt))
print("-" * 80)
# Out:
# Cognitive Verifier Output:
#
# **Prompt Engineering:**
#
# Prompt engineering is a technique used to optimize the performance of language models by designing effective and well-structured input prompts. The goal of prompt engineering is to create a prompt that can elicit the desired response from the model, improve its accuracy, and reduce errors. This involves experimenting with different wording, phrasing, and formatting to find the optimal combination that triggers the most accurate and relevant response.
#
# Prompt engineering involves several key steps:
#
# 1. **Analyzing the model's capabilities**: Understanding the strengths and limitations of the language model being used.
# 2. **Defining the task**: Clearly defining the task or question that needs to be answered.
# 3. **Crafting the prompt**: Designing a well-structured and focused prompt that elicits the desired response.
# 4. **Testing and refining**: Iteratively testing and refining the prompt to improve its performance.
#
# **Use cases for prompt engineering:**
#
# 1. **Chatbots**: Improving the accuracy and relevance of chatbot responses.
# 2. **Language generation**: Enhancing the quality and coherence of text generated by language models.
# 3. **Question answering**: Designing effective prompts to elicit accurate and relevant answers to complex questions.
# 4. **Conversational dialogue systems**: Optimizing prompts to improve the flow and coherence of conversational dialogue.
#
# **Verification:**
#
# My response is verified to be accurate, up-to-date, and covers the essential aspects of prompt engineering.
#
# **Missing information:**
#
# Additional topics that could be explored in more depth in the context of prompt engineering include:
#
# 1. **Prompting techniques**: Specific techniques, such as using active voice, asking multiple questions, or using specific formatting, that can improve prompt performance.
# 2. **Evaluation metrics**: Metrics and methods for evaluating the effectiveness of prompts, such as accuracy, fluency, and relevance.
# 3. **Prompt engineering tools**: Tools and platforms that can aid in prompt engineering, such as prompt generators or evaluation metrics.
# 4. **Real-world applications**: Case studies or examples of prompt engineering in real-world applications, such as customer service chatbots or language translation systems.
# --------------------------------------------------------------------------------

# %% [markdown]
# 4. Question Refinement Pattern
# Used when a question is too vague or unclear.
# AI rewrites it into a better, more precise question.

# %%
question_refinement_prompt = """
Refine the following question to make it clearer:
"What is AI?"
"""

print("Question Refinement Output:\n")
print(ask_ai(question_refinement_prompt))
print("-" * 80)
# Out:
# Question Refinement Output:
#
# Here are some possible refinements of the question to make it clearer:
#
# 1. "Can you explain what Artificial Intelligence (AI) is, and how it differs from other forms of automation?"
# 2. "What are the core principles and goals of Artificial Intelligence, and how is it defined by experts in the field?"
# 3. "Can you provide an overview of the concept of Artificial Intelligence, including its history, key technologies, and current applications?"
# 4. "What are the most common types of Artificial Intelligence, such as Narrow or General AI, and how do they differ in terms of capabilities and limitations?"
# 5. "Can you give a detailed definition of Artificial Intelligence, including its components, characteristics, and any key concepts that underlie its functionality?"
#
# These refinements help to clarify the scope and intent of the question, making it easier for the respondent to provide a more specific and accurate answer.
# --------------------------------------------------------------------------------

# %%
new_info_prompt = """
Explain Machine Learning.
Provide new related information.
Then ask two follow-up questions.
"""

print("Provide New Info & Ask Questions Output:\n")
print(ask_ai(new_info_prompt))
print("-" * 80)
# Out:
# Provide New Info & Ask Questions Output:
#
# **What is Machine Learning?**
#
# Machine Learning (ML) is a subset of Artificial Intelligence (AI) that involves training algorithms to learn from data and make predictions or decisions with minimal human intervention. It's a key area of research and development in the field of computer science, and has numerous applications in areas such as image and speech recognition, natural language processing, and predictive analytics.
#
# The core idea of machine learning is to enable computers to identify patterns and relationships in data, and to use that knowledge to make predictions or decisions. Machine learning algorithms are trained on data, which can come from a variety of sources such as images, text, audio, or sensor readings. The algorithm learns from the data by optimizing its parameters to minimize the error between its predictions and the actual outcomes.
#
# There are several types of machine learning:
#
# 1. **Supervised Learning**: The algorithm is trained on labeled data, where the correct output is known. The algorithm learns to map inputs to outputs based on the labeled data.
# 2. **Unsupervised Learning**: The algorithm is trained on unlabeled data, and it must find patterns or relationships in the data without any guidance.
# 3. **Reinforcement Learning**: The algorithm learns through trial and error, receiving feedback in the form of rewards or penalties.
#
# **New Related Information:**
#
# 1. **Explainable AI (XAI)**: As machine learning models become more complex and widespread, the need to understand how they make decisions has grown. Explainable AI is a new field that focuses on developing techniques to interpret and explain the decisions made by machine learning models.
# 2. **Transfer Learning**: This technique involves using a pre-trained machine learning model as a starting point for a new task. This can significantly speed up the training process and improve performance on the new task.
# 3. **Graph Neural Networks**: These are a type of neural network designed to handle graph-structured data, such as social networks, molecules, or traffic patterns.
#
# **Follow-up Questions:**
#
# 1. How does transfer learning benefit from pre-trained models with deep neural network architectures? What are the potential challenges associated with using pre-trained models?
# 2. What are some key challenges in building and deploying explainable AI models in real-world applications, and how can these challenges be addressed?
# --------------------------------------------------------------------------------

# %% [markdown]
# Provide New Information and Ask Questions
#
# The AI:
#
# Explains the topic
#
# Adds extra related knowledge
#
# Asks follow-up questions to continue learning
#
# Very useful for interactive learning.

# %%
new_info_prompt = """
Explain Machine Learning.
Provide new related information.
Then ask two follow-up questions.
"""

print("Provide New Info & Ask Questions Output:\n")
print(ask_ai(new_info_prompt))
print("-" * 80)
# Out:
# Provide New Info & Ask Questions Output:
#
# **What is Machine Learning?**
#
# Machine learning is a subset of artificial intelligence (AI) that enables computers to learn from data without being explicitly programmed. It involves training algorithms to make predictions, classify objects, or make decisions based on patterns in the data. The machine learning process typically involves the following steps:
#
# 1. **Data Collection**: Gathering relevant data to train the model.
# 2. **Data Preprocessing**: Cleaning, transforming, and preparing the data for training.
# 3. **Model Training**: Using algorithms to train the model on the preprocessed data.
# 4. **Model Evaluation**: Evaluating the performance of the trained model using metrics such as accuracy, precision, and recall.
# 5. **Model Deployment**: Deploying the trained model in a production environment to make predictions or recommendations.
#
# **Types of Machine Learning:**
#
# 1. **Supervised Learning**: This type of learning involves training the model on labeled data to predict the output for new, unseen data.
# 2. **Unsupervised Learning**: This type of learning involves training the model on unlabeled data to identify patterns or structures in the data.
# 3. **Reinforcement Learning**: This type of learning involves training the model to take actions in an environment to maximize a reward or minimize a penalty.
#
# **Some popular Machine Learning algorithms:**
#
# 1. **Linear Regression**: For predicting continuous values.
# 2. **Decision Trees**: For classifying data into different categories.
# 3. **Support Vector Machines (SVMs)**: For classifying data into different categories.
# 4. **Neural Networks**: For complex tasks such as image and voice recognition.
#
# **Recent advancements in Machine Learning:**
#
# 1. **Explainable AI (XAI)**: Techniques to explain the decisions made by machine learning models.
# 2. **Transfer Learning**: Using pre-trained models as a starting point for new tasks.
# 3. **Deep Learning**: A subset of machine learning that uses neural networks with multiple layers.
#
# **Follow-up questions:**
#
# 1. Can you explain the difference between overfitting and underfitting in machine learning?
# 2. How can transfer learning be used to improve the performance of a machine learning model for a specific task?
# --------------------------------------------------------------------------------

# %% [markdown]
# Exercise 4
# Chain of Thought, Tabular Format, Fill in the Blank, RGC, Zero-shot, One-shot, Few-shot Prompting

# %% [markdown]
# Chain of Thought Prompting
#
#
# AI explains its reasoning step by step, instead of jumping to the answer.
# Helps in understanding how decisions are made.

# %%
cot_prompt = """
Explain step by step how AI detects spam emails.
Show your reasoning clearly.
"""

print("Chain of Thought Output:\n")
print(ask_ai(cot_prompt))
print("-" * 80)
# Out:
# Chain of Thought Output:
#
# Here's a step-by-step explanation of how AI detects spam emails:
#
# **Step 1: Text Collection**
#
# The AI system collects text data from emails, including the header, subject, body, and any attachments. This data is stored in a database or a model for future processing.
#
# **Step 2: Data Preprocessing**
#
# The collected text data is preprocessed to remove any unnecessary information such as:
#
# * Stop words (common words like "the," "and," "is," etc.)
# * Punctuation
# * Special characters
# * HTML tags
# * Emojis
#
# This step helps to improve the accuracy of the spam detection model by removing noise from the data.
#
# **Step 3: Tokenization**
#
# The preprocessed text data is broken down into individual tokens or words. This step helps to analyze the text at a word level, which is essential for spam detection.
#
# **Step 4: Stemming or Lemmatization**
#
# The tokens are then stemmed or lemmatized to reduce words to their base or root form. For example, "running" becomes "run" or "running" becomes "run" (lemmatization considers the context and the part of speech). This step helps to group similar words together and reduce the dimensions of the data.
#
# **Step 5: Feature Extraction**
#
# The stemmed or lemmatized tokens are then used to extract features that can be used to distinguish spam from legitimate emails. Some common features used in spam detection include:
#
# * Uncommon words or phrases
# * Emotional language (e.g., exclamation marks, capital letters, etc.)
# * Slang or informal language
# * Suspicious URLs
# * Unsolicited offers or promises
# * Missing or mismatched information (e.g., sender, recipient, etc.)
#
# **Step 6: Modeling**
#
# The extracted features are then used to train a machine learning model, such as a Naive Bayes classifier or a Random Forest classifier. The model learns to recognize patterns in the data and predict whether an email is spam or not.
#
# **Step 7: Training**
#
# The model is then trained on a labeled dataset of emails, where each email is classified as spam or legitimate. The model learns to make predictions based on the features extracted in Step 5.
#
# **Step 8: Testing**
#
# The trained model is then tested on a separate dataset to evaluate its performance. The model is evaluated using metrics such as accuracy, precision, recall, and F1 score.
#
# **Step 9: Thresholding**
#
# Once the model is trained and tested, it is deployed in a production environment where it is used to classify new emails. The model outputs a probability score indicating the likelihood that an email is spam. A predetermined threshold is set to classify emails as spam if the probability score exceeds the threshold.
#
# **Step 10: Continuous Learning**
#
# The AI system is designed to continuously learn from new emails and update its model to improve its accuracy. This is done by retraining the model on new data and adjusting the threshold as needed.
#
# Reasoning:
#
# * AI detects spam emails by analyzing the text data and identifying patterns that are indicative of spam.
# * The model is trained on a labeled dataset to learn to recognize these patterns and make predictions.
# * The accuracy of the model is evaluated using various metrics, and the threshold is adjusted to achieve the desired level of accuracy.
# * The model is designed to continuously learn from new data and improve its accuracy over time.
#
# Note: This is a general explanation of the steps involved in spam detection using AI. The specific algorithms and techniques used may vary depending on the implementation and the requirements of the project.
# --------------------------------------------------------------------------------

# %% [markdown]
# Tabular Format Prompting
# Used when information needs comparison or structure.
# AI outputs data in table form.

# %%
tabular_prompt = """
Explain the difference between AI, ML, and Deep Learning in a table.
"""

print("Tabular Format Output:\n")
print(ask_ai(tabular_prompt))
print("-" * 80)
# Out:
# Tabular Format Output:
#
# Here's a table explaining the difference between Artificial Intelligence (AI), Machine Learning (ML), and Deep Learning (DL):
#
# | **Features** | **Artificial Intelligence (AI)** | **Machine Learning (ML)** | **Deep Learning (DL)** |
# | --- | --- | --- | --- |
# | **Definition** | AI refers to a broad field that aims to create intelligent machines that can perform tasks that would typically require human intelligence | ML is a subset of AI that focuses on developing algorithms that enable machines to learn from data and make decisions | DL is a type of ML that uses neural networks with multiple layers to analyze data |
# | **Types** | Narrow/Moderate/General AI | Supervised, Unsupervised, Reinforcement Learning | Neural Networks, Convolutional Neural Networks (CNN), Recurrent Neural Networks (RNN), Long Short-Term Memory (LSTM) |
# | **Goals** | Develop intelligent machines that can perform tasks autonomously | Develop algorithms that enable machines to learn from data and make decisions | Focus on developing neural networks that can learn from large amounts of data |
# | **Method** | Rule-based systems, Expert Systems | Training algorithms on data, Model selection, Model evaluation | Training large artificial neural networks on massive datasets |
# | **Complexity** | Can involve symbolic or rule-based methods | Can involve simple or complex methods, including regression, decision trees, and clustering | Requires massive amounts of data, computational power, and memory |
# | **Applications** | Virtual assistants, chatbots, expert systems, decision support systems | Image and speech recognition, natural language processing, predictive modeling, recommender systems | Self-driving cars, image recognition, speech recognition, natural language processing |
#
# To illustrate the hierarchy:
#
# - AI is the overarching field that encompasses various subfields, including Machine Learning.
# - Machine Learning is a subset of AI, which includes various types of learning:
#   * Supervised, Unsupervised, Reinforcement Learning.
# - Deep Learning is a type of Machine Learning that focuses on developing neural networks with multiple layers to analyze data and perform tasks.
#
# In summary, AI is a broad field that aims to create intelligent machines, Machine Learning is a subset of AI that focuses on developing algorithms to enable machines to learn from data, and Deep Learning is a type of Machine Learning that uses neural networks to analyze large amounts of data.
# --------------------------------------------------------------------------------

# %% [markdown]
# Fill in the Blank Prompting
# AI completes missing information.
# Commonly used in education and assessments.

# %%
fill_blank_prompt = """
Fill in the blank:
Artificial Intelligence is the ability of machines to ______ human intelligence.
"""

print("Fill in the Blank Output:\n")
print(ask_ai(fill_blank_prompt))
print("-" * 80)
# Out:
# Fill in the Blank Output:
#
# Artificial Intelligence is the ability of machines to **mimic** or **replicate** human intelligence.
# --------------------------------------------------------------------------------

# %% [markdown]
# RGC (Role–Goal–Context) Prompting
#
# Prompt is structured using:
#
# Role – Who AI is
#
# Goal – What AI should do
#
# Context – Situation of the user
#
# Produces highly relevant answers.

# %%
rgc_prompt = """
Role: You are an AI mentor.
Goal: Explain prompt engineering.
Context: The learner is a beginner with no AI background.
"""

print("RGC Prompt Output:\n")
print(ask_ai(rgc_prompt))
print("-" * 80)
# Out:
# RGC Prompt Output:
#
# I'm excited to introduce you to the concept of prompt engineering. It's a fascinating field that combines natural language understanding, linguistics, and machine learning to design the right questions for AI models.
#
# **What is Prompt Engineering?**
#
# Prompt engineering is the art of crafting specific, concise, and informative input prompts that elicit the desired response from AI models. These prompts are designed to guide the AI to generate accurate, relevant, and engaging output.
#
# Think of it like ordering food at a restaurant. Imagine you want to ask for a juicy burger, but you phrase it as "Give me a huge salad with lettuce, tomatoes, and a side of fries." The restaurant might give you what you asked for, but it's not what you wanted. A prompt engineer would craft a prompt like "I'd like a classic cheeseburger, medium-rare, with fries on the side" to get the desired outcome.
#
# **Key aspects of Prompt Engineering:**
#
# 1. **Clear intent**: The prompt should clearly express what you want the AI to do.
# 2. **Relevant information**: Provide enough context for the AI to generate accurate output.
# 3. **Specific language**: Use precise and unambiguous words to avoid confusion.
# 4. **Contextual awareness**: Consider the AI's perspective and the task's requirements.
# 5. **Error tolerance**: Design the prompt to minimize the likelihood of errors or misinterpretations.
#
# **Benefits of Prompt Engineering:**
#
# 1. **Improves AI performance**: By crafting better prompts, you can increase the accuracy and relevance of AI output.
# 2. **Enhances user experience**: Well-designed prompts make it easier for users to communicate with AI systems.
# 3. **Faster development**: With effective prompts, you can train AI models more efficiently and achieve better results.
#
# **Examples of Prompt Engineering:**
#
# 1. **Language translation**: "Translate 'Hello, how are you?' from English to Spanish" vs. "Can you help me convert this text into Spanish?"
# 2. **Image classification**: "Show me pictures of cats and dogs" vs. "Display images of animals with a breed identification"
# 3. **Text summarization**: "Please summarize this article into 2-3 sentences" vs. "Can you condense this large text into a shorter version?"
#
# Now that you've been introduced to prompt engineering, I'd like you to practice designing some prompts. We'll work together to create clear and effective input for AI models. Do you have any specific ideas or scenarios in mind you'd like to work on?
# --------------------------------------------------------------------------------

# %% [markdown]
# Zero-Shot Prompting
#
# No examples are provided.
# AI answers purely based on its training.

# %%
zero_shot_prompt = """
Explain Natural Language Processing.
"""

print("Zero-Shot Output:\n")
print(ask_ai(zero_shot_prompt))
print("-" * 80)
# Out:
# Zero-Shot Output:
#
# **Natural Language Processing (NLP)**
#
# Natural Language Processing (NLP) is a subfield of artificial intelligence (AI) that deals with the interaction between computers and humans in natural language. It is a branch of computer science and linguistics that seeks to understand, interpret, and generate human language, aiming to enable computers to process, analyze, and generate natural language data.
#
# **Key Goals of NLP:**
#
# 1. **Language Understanding**: NLP aims to comprehend the meaning and context of human language, enabling computers to interpret and respond accordingly.
# 2. **Language Generation**: NLP enables computers to generate human-like language, such as text or speech, for various applications, like chatbots, voice assistants, or language translation.
# 3. **Language Recognition**: NLP involves recognizing and classifying specific language patterns, such as sentiment analysis, entity extraction, or intent identification.
#
# **NLP Techniques:**
#
# 1. **Text Preprocessing**: Cleaning and preparing text data for analysis, which includes tokenization, stemming, and lemmatization.
# 2. **Part-of-Speech (POS) Tagging**: Identifying the grammatical categories of words in a sentence, such as nouns, verbs, or adjectives.
# 3. **Named Entity Recognition (NER)**: Identifying specific entities in text, such as names, locations, or organizations.
# 4. **Sentiment Analysis**: Determining the emotional tone or sentiment of text, such as positive, negative, or neutral.
# 5. **Language Translation**: Translating text from one language to another.
# 6. **Question Answering**: Identifying answers to specific questions based on text data.
# 7. **Machine Learning**: Employing machine learning algorithms to learn from labeled data and improve NLP performance.
#
# **NLP Applications:**
#
# 1. **Virtual Assistants**: Siri, Alexa, and Google Assistant rely on NLP to understand voice commands and respond accordingly.
# 2. **Chatbots**: Chatbots use NLP to interact with users, answer questions, and perform tasks.
# 3. **Language Translation**: Google Translate, Microsoft Translator, and other translation tools use NLP to translate text and speech.
# 4. **Sentiment Analysis**: Analyzing customer feedback, social media, and review data to understand public opinion.
# 5. **Speech Recognition**: Recognizing spoken language and transcribing it into text.
#
# **NLP Challenges:**
#
# 1. **Semantic Understanding**: Dealing with ambiguity, nuances, and context in human language.
# 2. **Ambiguity**: Resolving meaning and context when words or sentences can have multiple interpretations.
# 3. **Limited Training Data**: NLP models require large amounts of high-quality training data to achieve accuracy.
# 4. **Sarcasm and Idioms**: Handling language that is intentionally ambiguous or metaphorical.
#
# By overcoming these challenges, NLP has the potential to revolutionize the way computers interact with humans, enabling more natural and intuitive communication.
# --------------------------------------------------------------------------------

# %% [markdown]
# One-Shot Prompting
#
# Explanation
#
# One example is given so AI follows the same pattern.

# %%
one_shot_prompt = """
Example:
Input: What is AI?
Output: AI is the simulation of human intelligence by machines.

Now explain:
What is Machine Learning?
"""

print("One-Shot Output:\n")
print(ask_ai(one_shot_prompt))
print("-" * 80)
# Out:
# One-Shot Output:
#
# Machine Learning is the ability of a machine or computer to learn from data without being explicitly programmed for each task.
# --------------------------------------------------------------------------------

# %% [markdown]
# Few-Shot Prompting
#
# Explanation
#
# Multiple examples are provided.
# AI learns the pattern and completes the task.

# %%
few_shot_prompt = """
Input: AI
Output: Machines that simulate human intelligence.

Input: ML
Output: Systems that learn from data.

Input: Deep Learning
Output:
"""

print("Few-Shot Output:\n")
print(ask_ai(few_shot_prompt))
print("-" * 80)
# Out:
# Few-Shot Output:
#
# Input: Deep Learning
# Output: A subset of machine learning that uses multiple layers of neural networks to analyze and interpret complex data.
# --------------------------------------------------------------------------------
